# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithya-collab/BioDrop/blob/main/Shortest%20Path%20Optimization%20on%20a%20Small%20Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#     **Shortest Path Optimization on a Small Grid**
